# %% [markdown]
# # Wildfire Risk - Ingest - S3 Setup
# __Team 3 - Dave Friesen, John Chen, and Kyle Dalope__<br>
# __ADS-508-02-SP23__<br><br>
# __GitHub link: https://github.com/davefriesen/wildfire-risk__

# %%
__authors__ = ['Dave Friesen', 'John Chen', 'Kyle Dalope']
__contact__ = ['dfriesen@sandiego.edu', 'johnchen@sandiego.edu', 'kdalope@sandiego.edu']
__date__ = '2023-03-20'
__license__ = 'MIT'
__version__ = '1.0.1'

# %% [markdown]
# # Setup Basics

# %%
# Import basic libraries
import boto3
import sagemaker

# Import data access libraries
import pandas as pd
from profiler import profile, profile_cat

# %%
# Establish session fundamentals
sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
account_id = boto3.Session().client(service_name='sagemaker', region_name=region)

# %% [markdown]
# # Setup S3

# %%
# Set public path and store as SageMaker variable
s3_public_path = 's3://wildfire-risk/'
# %store s3_public_path

# Set private path ("my bucket")
s3_private_path = 's3://{}/widfire-risk/csv/'.format(bucket)
# %store s3_private_path
print(s3_private_path)
# Out:
# Stored 's3_public_path' (str)
# Stored 's3_private_path' (str)
# s3://sagemaker-us-east-1-857283526476/widfire-risk/csv/

# %%
# Get contents of Public S3 bucket (file source)
# !aws s3 ls {s3_public_path}
# Out:
# 2023-03-24 02:49:22    8623294 conditions.csv
# 2023-03-18 23:31:25   10821874 fires.csv
# 2023-03-18 23:31:21   38317925 weather.csv

# %%
# Now copy public bucket-based data to private (local) bucket
# !aws s3 cp --recursive $s3_public_path $s3_private_path --exclude '*' --include 'fires.csv'
# !aws s3 cp --recursive $s3_public_path $s3_private_path --exclude '*' --include 'weather.csv'
# !aws s3 cp --recursive $s3_public_path $s3_private_path --exclude '*' --include 'conditions.csv'
# Out:
# copy: s3://wildfire-risk/fires.csv to s3://sagemaker-us-east-1-857283526476/widfire-risk/csv/fires.csv
# copy: s3://wildfire-risk/weather.csv to s3://sagemaker-us-east-1-857283526476/widfire-risk/csv/weather.csv
# copy: s3://wildfire-risk/conditions.csv to s3://sagemaker-us-east-1-857283526476/widfire-risk/csv/conditions.csv

# %%
# List contents of private S3 bucket to confirm copy
# !aws s3 ls $s3_private_path
# Out:
# 2023-03-27 03:20:27    8623294 conditions.csv
# 2023-03-27 03:20:24   10821874 fires.csv
# 2023-03-27 03:20:25   38317925 weather.csv

# %% [markdown]
# # Load and Validate Data (*traditional Pandas - as check*)

# %%
# Load and check base data files from public S3 bucket
fires_df = pd.read_csv(s3_private_path+'fires.csv')
weather_df = pd.read_csv(s3_private_path+'weather.csv')
profile(fires_df)
profile(weather_df)
# Out:
#                             Dtype  count unique     na   na%       mean  \
# ContainmentDateTime        object  35315  33108  53847  60.4
# ControlDateTime            object  32570  30401  56592  63.5
# DiscoveryAcres            float64  72195    348  16967  19.0        5.8
# EstimatedCostToDate       float64   2128   1040  87034  97.6  8193477.0
# FinalAcres                float64   2631    345  86531  97.0       14.9
# FireBehaviorGeneral        object   1498      4  87664  98.3
# FireBehaviorGeneral1       object   1223     16  87939  98.6
# FireBehaviorGeneral2       object   1164     16  87998  98.7
# FireBehaviorGeneral3       object    910     16  88252  99.0
# FireCause                  object  77967      4  11195  12.6
# FireCauseGeneral           object   7825     14  81337  91.2
# FireCauseSpecific          object   2404     66  86758  97.3
# FireDiscoveryDateTime      object  89162  87931
# FireOutDateTime            object  32551  28437  56611  63.5
# GACC                       object  89145      7     17
# IncidentName               object  89162  57671
# IncidentShortDescription   object   1396   1346  87766  98.4
# InitialLatitude           float64  73484  59993  15678  17.6       39.0
# InitialLongitude          float64  73484  54067  15678  17.6     -119.7
# IsFireCauseInvestigated   float64   2375      2  86787  97.3        0.8
# IsTrespass                float64  57008      2  32154  36.1        0.1
# POOCity                    object   1090    707  88072  98.8
# POOState                   object  89162      3
# PredominantFuelModel       object   7035     42  82127  92.1
# PrimaryFuelModel           object   1730     12  87432  98.1
#
#                                  std     min          max skew(>=3) <v0.01  \
# ContainmentDateTime
# ControlDateTime
# DiscoveryAcres                 500.0             115997.0     191.8
# EstimatedCostToDate       34440012.7          800000000.0      13.1
# FinalAcres                     318.1              13440.0      34.3
# FireBehaviorGeneral
# FireBehaviorGeneral1
# FireBehaviorGeneral2
# FireBehaviorGeneral3
# FireCause
# FireCauseGeneral
# FireCauseSpecific
# FireDiscoveryDateTime
# FireOutDateTime
# GACC
# IncidentName
# IncidentShortDescription
# InitialLatitude                  5.0                 77.4
# InitialLongitude                 2.9  -134.6        119.3      25.5
# IsFireCauseInvestigated          0.4                  1.0
# IsTrespass                       0.3                  1.0
# POOCity
# POOState
# PredominantFuelModel
# PrimaryFuelModel
#
#                          VIF(>=10)              examples
# ContainmentDateTime                 2015/08/26 19:40:00+
# ControlDateTime                     2015/08/27 15:59:59+
# DiscoveryAcres                      0.25__0.1__nan__0.1_
# EstimatedCostToDate                 nan__nan__nan__nan__
# FinalAcres                          nan__nan__nan__nan__
# FireBehaviorGeneral                 nan__nan__nan__nan__
# FireBehaviorGeneral1                nan__nan__nan__nan__
# FireBehaviorGeneral2                nan__nan__nan__nan__
# FireBehaviorGeneral3                nan__nan__nan__nan__
# FireCause                           Human__Undetermined_
# FireCauseGeneral                    nan__nan__nan__nan__
# FireCauseSpecific                   nan__nan__nan__nan__
# FireDiscoveryDateTime               2015/08/26 17:46:39+
# FireOutDateTime                     2015/09/04 22:28:59+
# GACC                                NWCC__OSCC__ONCC__OS
# IncidentName                        AIRPORT EXIT__LINCOL
# IncidentShortDescription            nan__nan__nan__nan__
# InitialLatitude               72.5  47.6345__33.886673__
# InitialLongitude              72.4  -117.4809__-117.5059
# IsFireCauseInvestigated             nan__nan__nan__nan__
# IsTrespass                          0.0__0.0__0.0__0.0__
# POOCity                             nan__nan__nan__nan__
# POOState                            US-WA__US-CA__US-CA_
# PredominantFuelModel                nan__nan__nan__nan__
# PrimaryFuelModel                    nan__nan__nan__nan__
#                    Dtype   count unique     na   na%    mean     std     min  \
# STATION           object  175300    610
# DATE              object  175300    461
# LATITUDE         float64  175300    600                 40.1     3.9    32.6
# LONGITUDE        float64  175300    590               -118.0     6.3  -124.4
# ELEVATION        float64  175300    472               1214.0   734.3
# NAME              object  175300    610
# CDSD             float64  148117  11831  27183  15.5   182.8   315.5
# CDSD_ATTRIBUTES   object  143784      1  31516  18.0
# CLDD             float64  174374   4080    926   0.5    34.0    67.2
# CLDD_ATTRIBUTES   object  174374      6    926   0.5
# DT00             float64  174954     27    346   0.2     0.2     1.2
# DT00_ATTRIBUTES   object  174954      8    346   0.2
# DT32             float64  174954     32    346   0.2     8.6    10.7
# DT32_ATTRIBUTES   object  174954      6    346   0.2
# DX32             float64  175086     32    214   0.1     1.3     3.6
# DX32_ATTRIBUTES   object  175086      6    214   0.1
# DX70             float64  175086     32    214   0.1    12.3    11.9
# DX70_ATTRIBUTES   object  175086      6    214   0.1
# DX90             float64  175086     32    214   0.1     2.8     6.4
# DX90_ATTRIBUTES   object  175086      6    214   0.1
# EMNT             float64  174954    420    346   0.2    -1.7     8.9   -41.1
# EMNT_ATTRIBUTES   object  174954    352    346   0.2
# EMXT             float64  175086    359    214   0.1    26.1     9.0    -3.3
# EMXT_ATTRIBUTES   object  175086    352    214   0.1
# HDSD             float64  151739  40090  23561  13.4  1268.5  1298.0
# HDSD_ATTRIBUTES   object  146766      1  28534  16.3
# HTDD             float64  174374   8372    926   0.5   241.9   201.3
# HTDD_ATTRIBUTES   object  174374      6    926   0.5
# TAVG             float64  174740   4619    560   0.3    11.4     8.2   -17.1
# TAVG_ATTRIBUTES   object  174740     10    560   0.3
# TMAX             float64  175086   4886    214   0.1    17.8     9.4   -11.1
# TMAX_ATTRIBUTES   object  175086      6    214   0.1
# TMIN             float64  174954   4579    346   0.2     5.0     7.4   -24.1
# TMIN_ATTRIBUTES   object  174954      6    346   0.2
#
#                     max skew(>=3) <v0.01 VIF(>=10)              examples
# STATION                                             USR0000CHOO__USR0000
# DATE                                                2001-09__2000-07__20
# LATITUDE           49.0                      131.0  41.0478__38.8825__42
# LONGITUDE         -82.4                      266.0  -123.6714__-121.2683
# ELEVATION        3694.2                             114.3__61.0__975.4__
# NAME                                                HOOPA CALIFORNIA, CA
# CDSD             3218.1       3.1                   383.2__426.2__23.4__
# CDSD_ATTRIBUTES                                            U__U__U__U__U
# CLDD              601.0                       23.0  71.2__167.7__20.6__5
# CLDD_ATTRIBUTES                                      ,U__,U__,U__1,U__,U
# DT00               26.0       8.4                   0.0__0.0__0.0__0.0__
# DT00_ATTRIBUTES                                      ,U__,U__,U__1,U__,U
# DT32               31.0                       20.7  0.0__0.0__0.0__0.0__
# DT32_ATTRIBUTES                                      ,U__,U__,U__1,U__,U
# DX32               31.0       3.9                   0.0__0.0__0.0__0.0__
# DX32_ATTRIBUTES                                       ,U__,U__,U__,U__,U
# DX70               31.0                       32.5  29.0__31.0__18.0__25
# DX70_ATTRIBUTES                                       ,U__,U__,U__,U__,U
# DX90               31.0                       10.3  13.0__21.0__1.0__2.0
# DX90_ATTRIBUTES                                       ,U__,U__,U__,U__,U
# EMNT               28.3                       15.0  6.7__10.6__1.1__7.2_
# EMNT_ATTRIBUTES                                     ,U,22,+__,U,04,__,U,
# EMXT               53.9                      133.4  39.4__41.1__35.0__33
# EMXT_ATTRIBUTES                                     ,U,07,__,U,31,__,U,1
# HDSD             7681.9                             13.6__0.0__2404.2__4
# HDSD_ATTRIBUTES                                          U__U__U__U__nan
# HTDD             1095.4                       82.3  12.0__0.0__138.6__43
# HTDD_ATTRIBUTES                                       ,U__,U__,U__,U__,U
# TAVG               37.7                      893.5  20.31__23.74__14.53_
# TAVG_ATTRIBUTES                                      ,U__,U__,U__1,U__,U
# TMAX               45.2                      737.0  30.71__33.6__21.66__
# TMAX_ATTRIBUTES                                     ,,,U__,,,U__,,,U__,,
# TMIN               31.8                      181.1  9.91__13.89__7.39__1
# TMIN_ATTRIBUTES                                     ,,,U__,,,U__,,,U__1,

# %% [markdown]
# # Store Variables and Close Session

# %%
# Store variables for subsequent notebooks
# %store
# Out:
# Stored variables and their in-db values:
# autopilot_train_s3_uri                                -> 's3://sagemaker-us-east-1-857283526476/data/amazon
# balanced_bias_data_jsonlines_s3_uri                   -> 's3://sagemaker-us-east-1-857283526476/bias-detect
# balanced_bias_data_s3_uri                             -> 's3://sagemaker-us-east-1-857283526476/bias-detect
# bias_data_s3_uri                                      -> 's3://sagemaker-us-east-1-857283526476/bias-detect
# ingest_create_athena_db_passed                        -> True
# ingest_create_athena_table_parquet_passed             -> True
# ingest_create_athena_table_passed                     -> True
# ingest_create_athena_table_tsv_passed                 -> True
# s3_private_path                                       -> 's3://sagemaker-us-east-1-857283526476/widfire-ris
# s3_private_path_tsv                                   -> 's3://sagemaker-us-east-1-857283526476/amazon-revi
# s3_public_path                                        -> 's3://wildfire-risk/'
# s3_public_path_tsv                                    -> 's3://amazon-reviews-pds/tsv'
# setup_dependencies_passed                             -> True
# setup_iam_roles_passed                                -> True
# setup_instance_check_passed                           -> True
# setup_s3_bucket_passed                                -> True

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
